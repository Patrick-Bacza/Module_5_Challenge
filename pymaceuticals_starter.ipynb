# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset

animal_study_df = pd.merge(mouse_metadata , study_results , on="Mouse ID")

# Display the data table for preview

animal_study_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
animal_study_df["Mouse ID"].nunique()
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
animal_study_df[animal_study_df.duplicated(subset=["Mouse ID" , "Timepoint"]) == True]["Mouse ID"]
# Out:
# 909    g989
# 911    g989
# 913    g989
# 915    g989
# 917    g989
# Name: Mouse ID, dtype: object

# %%
# Optional: Get all the data for the duplicate mouse ID. 
animal_study_df[animal_study_df.duplicated(subset=["Mouse ID" , "Timepoint"]) == True]
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID

clean_animal_study_df = animal_study_df[animal_study_df["Mouse ID"] != "g989"]

# %%
# Checking the number of mice in the clean DataFrame.

clean_animal_study_df["Mouse ID"].nunique()
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
tumor_volume_mean = clean_animal_study_df.groupby("Drug Regimen").mean()["Tumor Volume (mm3)"]
tumor_volume_median = clean_animal_study_df.groupby("Drug Regimen").median()["Tumor Volume (mm3)"]
tumor_volume_variance = clean_animal_study_df.groupby("Drug Regimen").var()["Tumor Volume (mm3)"]
tumor_volume_stdev = clean_animal_study_df.groupby("Drug Regimen").std()["Tumor Volume (mm3)"]
tumor_volume_sem = clean_animal_study_df.groupby("Drug Regimen").sem()["Tumor Volume (mm3)"]

summary_statistics = pd.DataFrame({
                "Mean Tumor Volume" : tumor_volume_mean,
                "Median Tumor Volume"  : tumor_volume_median,
                "Variance of Tumor Volume":  tumor_volume_variance ,
                "Std. Dev" : tumor_volume_stdev,
                "Std. Err" : tumor_volume_sem 
})

summary_statistics
# Out:
#               Mean Tumor Volume  Median Tumor Volume  \
# Drug Regimen
# Capomulin             40.675741            41.557809
# Ceftamin              52.591172            51.776157
# Infubinol             52.884795            51.820584
# Ketapril              55.235638            53.698743
# Naftisol              54.331565            52.509285
# Placebo               54.033581            52.288934
# Propriva              52.320930            50.446266
# Ramicane              40.216745            40.673236
# Stelasyn              54.233149            52.431737
# Zoniferol             53.236507            51.818479
#
#               Variance of Tumor Volume  Std. Dev  Std. Err
# Drug Regimen
# Capomulin                    24.947764  4.994774  0.329346
# Ceftamin                     39.290177  6.268188  0.469821
# Infubinol                    43.128684  6.567243  0.492236
# Ketapril                     68.553577  8.279709  0.603860
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line.

(clean_animal_study_df
            .groupby("Drug Regimen")
            .agg({"Tumor Volume (mm3)" : ['mean' , 'median'  , 'var' , 'std' , 'sem' ]}))
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
(clean_animal_study_df
        .groupby("Drug Regimen")
        .sum()["Timepoint"]
        .plot(kind="bar" , title="Timepoints for Mice Per Drug Regimen"))

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
drug_regimen = pd.DataFrame(clean_animal_study_df.groupby("Drug Regimen").sum()["Timepoint"])

plt.bar(drug_regimen.index , drug_regimen['Timepoint'])
plt.tick_params(axis= 'x' , rotation=90)
plt.title("Timepoints for Mice Per Drug Regimen")
plt.ylabel("Timepoints")
# Out:
# Text(0, 0.5, 'Timepoints')

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

clean_animal_study_df["Sex"].value_counts().plot(kind='pie' , autopct="%.1f%%" )

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
gender_totals = [clean_animal_study_df["Sex"].value_counts()[0] , clean_animal_study_df["Sex"].value_counts()[1]]
genders = ['Male' , 'Female']
colors = ['blue' , 'orange']

plt.pie(gender_totals, labels=genders,autopct="%1.1f%%",  shadow=False)
plt.ylabel('Sex')
# Out:
# Text(0, 0.5, 'Sex')

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
max_timepoint_df = clean_animal_study_df.groupby("Mouse ID").max()['Timepoint']


# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
tumor_volume_df = pd.merge(clean_animal_study_df , max_timepoint_df , on=['Mouse ID' , 'Timepoint'])

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)

tumor_volume = []



# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
        
    # add subset      
    # Determine outliers using upper and lower bound.
# Out:
#   Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane    Male          21          16         45
# 1     s185    Capomulin  Female           3          17         45
# 2     x401    Capomulin  Female          16          15         45
# 3     m601    Capomulin    Male          22          17         45
# 4     g791     Ramicane    Male          11          16         45
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           22.050126                 1
# 1           23.343598                 1
# 2           28.484033                 0
# 3           28.430964                 1
# 4           29.128472                 1

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
#clean_animal_study_df[clean_animal_study_df["Drug Regimen"] == 'Capomulin']

mouse_l509 = clean_animal_study_df[clean_animal_study_df['Mouse ID'] == 'l509']

mouse_l509.plot('Timepoint' , 'Tumor Volume (mm3)', title='Capomulin treatment of Mouse l509')
plt.ylabel('Tumor Volume (mm3)')
# Out:
# Text(0, 0.5, 'Tumor Volume (mm3)')

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
mask = clean_animal_study_df['Drug Regimen'] == 'Capomulin'

capomulin_regimen = clean_animal_study_df[mask].groupby("Mouse ID").mean()[['Weight (g)' , 'Tumor Volume (mm3)']]


plt.scatter(capomulin_regimen['Weight (g)'] , capomulin_regimen["Tumor Volume (mm3)"])
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
# Out:
# Text(0, 0.5, 'Average Tumor Volume (mm3)')

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

correlation_coefficeint = st.pearsonr(capomulin_regimen['Weight (g)'] , capomulin_regimen["Tumor Volume (mm3)"])

slope , intercept , r_squared , p_value , std_err = st.linregress(capomulin_regimen['Weight (g)']  , capomulin_regimen["Tumor Volume (mm3)"])

# %%
print(f"The correlation between mouse weight and the average tumor volume is {round(correlation_coefficeint[0],2)}")

regress_values = (capomulin_regimen["Weight (g)"] * slope + intercept)
plt.scatter(capomulin_regimen['Weight (g)'] , capomulin_regimen["Tumor Volume (mm3)"])
plt.plot(capomulin_regimen['Weight (g)'] , regress_values , "r-")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title("Average Tumor Volume vs. Mouse Weight")
plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
